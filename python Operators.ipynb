# %% [markdown]
# ## python Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Arthematic Operators
# + (Addition)
# - (Subtraction)
# * (Multiplication)
# / (Division)
# // Floor division)
# ℅ (Modulus)
# ** (Exponentiation)

# %%
# addition operator
a=10
b=5
c=a+b
print(c)

# subtraction
print(a-b)
# Out:
# 15
# 5

# %%
# erw
